# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
df = pd.read_csv("data/raw/malaysia_food_nutrition.csv")

df.head()
# Out:
#                Food_Item Category  Calories(kcal)  Protein(g)  Carbs(g)  \
# 0             Nasi Lemak     Rice             610          16        57
# 1       Mee Goreng Mamak  Noodles             480          18        60
# 2             Roti Canai    Bread             320           8        40
# 3  Char Kuey Teow Penang  Noodles             740          22        65
# 4    Nasi Goreng Kampung     Rice             560          14        70
#
#    Fat(g)  Sugar(g)  Sodium(mg)  Meal_Type
# 0      32         4         900  Breakfast
# 1      20         5         780      Lunch
# 2      12         3         450  Breakfast
# 3      38         6        1180      Lunch
# 4      20         5         980     Dinner
